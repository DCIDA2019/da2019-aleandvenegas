# %%
#LECTURA DE ARCHIVOS Y ACCESO DE BASES DE DATOS
import numpy as np
sunspots=np.loadtxt('sunspots.txt',dtype='i4')

# %%
import pandas as pd

# %%
tabulador=pd.read_excel('tabulador_pe2019.xls',header=9)

# %%
pd.read_excel
# Out:
# <function pandas.io.excel.read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=True, **kwds)>

# %%
tabulador.describe
# Out:
# <bound method NDFrame.describe of     NIVEL TIPO                            PUESTO   SUELDO BASE  \
# 0      22  NaN           GOBERNADOR/A DEL ESTADO  59804.327930
# 1      20  NaN          SECRETARIO/A DE ESTADO A  49025.945517
# 2      19  NaN  DIRECTOR/A GENERAL PARAESTATAL A  40685.951590
# 3      19  NaN          SECRETARIO/A DE ESTADO B  40685.951590
# 4      18  NaN          SECRETARIO/A DE ESTADO C  37083.708634
# 5      18  NaN                 SUBSECRETARIO/A A  37083.708634
# 6      18  NaN  DIRECTOR/A GENERAL PARAESTATAL B  37083.708634
# 7      17  NaN                 SUBSECRETARIO/A B  36196.185147
# 8      17  NaN  DIRECTOR/A GENERAL PARAESTATAL C  36196.185147
# 9      16  NaN                 SUBSECRETARIO/A C  29462.206543
# 10     16  NaN  DIRECTOR/A GENERAL PARAESTATAL D  29462.206543
# 11     16  NaN           COORDINADOR/A GENERAL A  29462.206543
# 12     15  NaN                 SUBSECRETARIO/A D  25790.604996
# ...

# %%
import requests
import lxml
import os as os

# %%
file='salarios_minimos.csv'
url="https://idconline.mx/laboral/salarios-minimos/salarios-minimos-1986-2007"
html=requests.get(url).content
df_list=pd.read_html(html,header=0)
df=df_list[-1]
df.to_csv('salarios_minimos.csv')
df=pd.read_csv(file)
df
# Out:
#     Unnamed: 0 Fecha de publicación el DOF  Vigente a partir de:  \
# 0            0                       ZLFN1        Resto del país
# 1            1     26 de diciembre de 2018        1o. enero 2019
# 2            2     21 de diciembre de 2017        1o. enero 2018
# 3            3     24 de noviembre de 2017    1o. diciembre 2017
# 4            4     19 de diciembre de 2016        1o. enero 2017
# 5            5     18 de diciembre de 2015        1o. enero 2016
# 6            6    30 de septiembre de 2015   1o. octubre de 2015
# 7            7         30 de marzo de 2015        1o. abril 2015
# 8            8     29 de diciembre de 2014        1o. enero 2015
# 9            9     26 de diciembre de 2013        1o. enero 2014
# 10          10     21 de diciembre de 2012        1o. enero 2013
# 11          11     26 de noviembre de 2012  27 de noviembre 2012
# 12          12     19 de diciembre de 2011        1o. enero 2012
# ...

# %%
file='Libro1.csv'
df=pd.read_csv(file)
df
# Out:
#              LON        LAT  EDO CLAVE_SIH  \
# 0    -102.309722  21.895000  AGS     AGSAG
# 1    -102.466944  22.188611  AGS     ANVAG
# 2    -102.184167  21.738611  AGS     BRTAG
# 3    -102.712222  21.849167  AGS  CALVILLO
# 4    -102.676944  21.997500  AGS     CDRAG
# 5    -102.197222  22.007222  AGS     CHOAG
# 6    -102.189167  21.826667  AGS     CLVAG
# 7    -102.000000  21.896389  AGS     CNSAG
# 8    -102.296667  22.362778  AGS     CSOAG
# 9    -102.356944  22.121667  AGS     JCQAG
# 10   -102.788333  21.807500  AGS     MNLAG
# 11   -102.371667  21.780000  AGS     NGRAG
# 12   -102.001944  22.020556  AGS     NVLAG
# 13   -102.290556  21.850833  AGS     OBSAG
# 14   -102.465000  22.189167  AGS   P50ANIV
# 15   -101.966667  21.916667  AGS     PALAG
# 16   -102.291944  22.162500  AGS     PBLAG
# 17   -102.417222  22.141111  AGS     PECAG
# 18   -102.133333  22.202778  AGS     PTOAG
# 19   -102.437500  22.235000  AGS     PTRAG
# 20   -102.108889  21.885000  AGS     SNVAG
# ...

# %%
url="https://smn.cna.gob.mx/es/climatologia/temperaturas-y-lluvias/resumenes-mensuales-de-temperaturas-y-lluvias"
html=requests.get(url).content
df_list=pd.read_html(html,header=0)
df=df_list[-1]
df.to_csv('lluvia.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-53a11e663dcc> in <module>
#       1 url="https://smn.cna.gob.mx/es/climatologia/temperaturas-y-lluvias/resumenes-mensuales-de-temperaturas-y-lluvias"
#       2 html=requests.get(url).content
# ----> 3 df_list=pd.read_html(html,header=0)
#       4 df=df_list[-1]
#       5 df.to_csv('lluvia.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#     985                   decimal=decimal, converters=converters, na_values=na_values,
#     986                   keep_default_na=keep_default_na,
# --> 987                   displayed_only=displayed_only)
#
# ...
